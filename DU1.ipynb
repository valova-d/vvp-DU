# %%
import math

#1. část

def odmocnina(cislo, iterace):
    x = cislo
    for i in range (iterace):
        x = 0.5 * ((cislo/x)+x)
    return x

print(odmocnina(6,7))

y = math.sqrt(6)
print(y)
# Out:
# 2.449489742783178
# 2.449489742783178

# %%
# 2. část
import math

def vypocet (strana, vyska, polomerova_strana):
        for i in range (100):
            strana = math.sqrt((strana/2)**2 + (1- vyska)**2)
            vyska = math.sqrt(polomerova_strana**2 - (strana/2)**2)
            pi = strana*vyska*6*2**i # o jedno méně, protože pro obsah trojúhelníku bych stejně dělila dvěma
        return pi
vyska = math.sqrt(3/4)

print(vypocet(1, vyska, 1))

print(math.pi)


strana = 1
polomerova_strana = 1
iterace = 1
while (abs(pi - math.pi) > 0.000001):
        strana = math.sqrt((strana/2)**2 + (1- vyska)**2)
        vyska = math.sqrt(polomerova_strana**2 - (strana/2)**2)
        pi = strana*vyska*6*2**(iterace-1)
        iterace = iterace +1

print(iterace)
# Out:
# 3.1415926535897936
# 3.141592653589793
# 11

# %%
# 3. část
import math
a = 1/16
suma = 0
for i in range (100):
    suma = suma + (1/(2*(i+1)+1))*a
    a = a* (2*(i+2)-3)/(2*(i+2))/4

pi =12* ((odmocnina(3,1000)/-8)+ 0.5 - suma)
print(pi)
print(math.pi)

pii = 3
iterace = 1
suma = 0
a = 1/16
while (abs(math.pi- pii)>0.000001):
    suma = suma + (1/(2*(iterace)+1))*a
    a = a* (2*(iterace+1)-3)/(2*(iterace+1))/4
    pii =12* ((odmocnina(3,1000)/-8)+ 0.5 - suma)
    iterace = iterace + 1
    

print(iterace)
# Out:
# 3.1415926535897936
# 3.141592653589793
# 7
